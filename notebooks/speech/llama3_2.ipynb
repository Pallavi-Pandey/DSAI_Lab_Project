# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve > /dev/null 2>&1 &

# %%
# !ollama pull llama3.2

# %%
# !ollama run llama3.2 "Write a 2-line poem about data science."
# Out:
# Here is a 2-line poem about data science:
#
# With algorithms and models so fine,
# Data science weaves insights divine.

# %%
import subprocess

def ask_ollama(model, prompt):
    """
    Sends a prompt to an Ollama model and returns the response.
    """
    result = subprocess.run(
        ["ollama", "run", model],
        input=prompt,
        text=True,
        capture_output=True
    )
    return result.stdout.strip()


def generate_medical_response(user_type, user_input):
    """
    Generates different responses depending on whether the user is
    a doctor or a patient.
    """

    # ---- PROMPTS FOR DIFFERENT USERS ----
    doctor_prompt = f"""
You are a highly trained clinical medical assistant for DOCTORS.
Use clinical terminology, differential diagnosis, and medical reasoning.

Doctor Input:
{user_input}

Provide:
- Differential diagnoses
- Clinical interpretation
- Suggested tests or next steps
- Professional and concise medical language
    """

    patient_prompt = f"""
You are a friendly medical assistant for PATIENTS.
Explain medical concepts in simple, easy-to-understand language.

Patient Input:
{user_input}

Provide:
- Simple explanation
- Possible causes
- What they can do now
- Friendly, reassuring tone
    """

    # Select the correct prompt
    if user_type.lower() == "doctor":
        final_prompt = doctor_prompt
    elif user_type.lower() == "patient":
        final_prompt = patient_prompt
    else:
        return "Error: user_type must be 'doctor' or 'patient'."

    # ---- CALL OLLAMA ----
    output = ask_ollama("llama3.2", final_prompt)
    return output


# -------------- MAIN PROGRAM -------------------

user_type = input("Are you a doctor or a patient? ").strip()
user_input = input("Enter your message: ").strip()

response = generate_medical_response(user_type, user_input)

print("\n--- AI Response ---")
print(response)
# Out:
# Are you a doctor or a patient? patient
# Enter your message: I am having a severe headace
#
# --- AI Response ---
# I'm so sorry to hear that you're experiencing a severe headache! Don't worry, I'm here to help you understand what's going on and offer some support.
#
# **What is a headache?**
# A headache is pain or discomfort in the head, neck, or face. It can be caused by many things, like tension, stress, or even something as simple as a lack of sleep.
#
# **Possible causes of severe headaches:**
# There are many possible reasons for severe headaches, and I'll try to break them down simply:
#
# 1. **Tension headaches**: These are the most common type of headache, often caused by muscle tension in the neck and scalp.
# 2. **Migraines**: These can be debilitating headaches that are usually accompanied by sensitivity to light and sound.
# 3. **Sinus pressure**: If your sinuses are congested or infected, it can cause pain in your forehead, cheeks, and eyes.
# 4. **Stress or anxiety**: Sometimes, our bodies can react to stress or anxiety with a headache.
#
# **What can you do now?**
# Don't worry; I'm here to help! Here are some things you can try right now:
#
# 1. **Stay hydrated**: Drink plenty of water to help your body relax and reduce headaches.
# 2. **Rest**: Take a break and give yourself permission to rest. Sometimes, our bodies just need a little R&R.
# 3. **Over-the-counter pain relief**: If you have a mild headache, you can try taking an over-the-counter pain reliever like acetaminophen (Tylenol) or ibuprofen (Advil).
# 4. **Stretching and relaxation techniques**: Try some gentle stretches, deep breathing exercises, or meditation to help calm your mind and body.
#
# **Remember:**
# If your headaches are severe, frequent, or accompanied by other symptoms like fever, confusion, or sensitivity to light, please seek medical attention right away. I'm here to support you, and we'll work together to figure out what's going on and find ways to make you feel better.
#
# Take care of yourself today, and don't hesitate to reach out if you need anything else!
